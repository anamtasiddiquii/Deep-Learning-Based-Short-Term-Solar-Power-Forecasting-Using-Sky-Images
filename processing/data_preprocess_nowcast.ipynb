# %%
# import packages 
import cv2
import numpy as np
import os
import datetime as dt
import time
import pandas as pd

# define your own folder paths and names
project_path = os.getcwd()
pv_data_folder = os.path.join(project_path,'pv_data','pv_output_valid.pkl')

image_folder = os.path.join(project_path,'snapshot_highfreq')
image_name_format = '%Y%m%d%H%M%S'

output_folder =  os.path.join(project_path,'data_expanded')
pred_folder = os.path.join(output_folder,'data_nowcast')

# operating parameter
output_img_shape = [64, 64, 3] # down-size the high-res image to this resolution
start_date = dt.datetime(2017,1,1) #NOTE: Inclusive of start date
end_date = dt.datetime(2020,1,1) #NOTE: Exclusive of end date (only end up with 2017-2019 data)

# %%
# Setting up test set
sunny_day = [(2017,9,15),(2017,10,6),(2017,10,22),(2018,2,16),(2018,6,12),(2018,6,23),(2019,1,25),(2019,6,23),(2019,7,14),(2019,10,14)]
cloudy_day = [(2017,6,24),(2017,9,20),(2017,10,11),(2018,1,25),(2018,3,9),(2018,10,4),(2019,5,27),(2019,6,28),(2019,8,10),(2019,10,19)]
sunny_datetime = [dt.datetime(day[0],day[1],day[2]) for day in sunny_day]
cloudy_datetime = [dt.datetime(day[0],day[1],day[2]) for day in cloudy_day]
test_dates = sunny_datetime + cloudy_datetime

# %%
test_dates
# Out:
# [datetime.datetime(2017, 9, 15, 0, 0),
#  datetime.datetime(2017, 10, 6, 0, 0),
#  datetime.datetime(2017, 10, 22, 0, 0),
#  datetime.datetime(2018, 2, 16, 0, 0),
#  datetime.datetime(2018, 6, 12, 0, 0),
#  datetime.datetime(2018, 6, 23, 0, 0),
#  datetime.datetime(2019, 1, 25, 0, 0),
#  datetime.datetime(2019, 6, 23, 0, 0),
#  datetime.datetime(2019, 7, 14, 0, 0),
#  datetime.datetime(2019, 10, 14, 0, 0),
#  datetime.datetime(2017, 6, 24, 0, 0),
#  datetime.datetime(2017, 9, 20, 0, 0),
#  datetime.datetime(2017, 10, 11, 0, 0),
#  datetime.datetime(2018, 1, 25, 0, 0),
#  datetime.datetime(2018, 3, 9, 0, 0),
#  datetime.datetime(2018, 10, 4, 0, 0),
#  datetime.datetime(2019, 5, 27, 0, 0),
#  datetime.datetime(2019, 6, 28, 0, 0),
#  datetime.datetime(2019, 8, 10, 0, 0),
#  datetime.datetime(2019, 10, 19, 0, 0)]

# %%
def find_idx_with_dates(all_times,test_dates):
    idx=[]
    for test_day in test_dates:
        test_day_end = test_day + dt.timedelta(days = 1)
        idx+=np.nonzero((all_times>test_day)*(all_times<test_day_end))[0].tolist()
    return idx

# This two function does the same thing. Just that one is for np, the other for pd.
def find_time_within_nparray(time_array,time_point):
    probable_idx = np.searchsorted(time_array,time_point)
    
    # If the time point is after all the time in pv_data
    if probable_idx == len(time_array):
        return None   
    
    # See if the time point is actually a match 
    if time_array[probable_idx]== time_point: 
        return probable_idx
        
    else:
        return None

def find_time_within_pdseries(time_array,time_point):
    probable_idx = np.searchsorted(time_array,time_point)
    
    # If the time point is after all the time in pv_data
    if probable_idx == len(time_array):
        return None   
    
    # See if the time point is actually a match 
    if time_array[probable_idx]== time_point: 
        return probable_idx
        
    else:
        return None

def listdir_noini(path):
    f_list = []
    for f in os.listdir(path):
        _, file_extension = os.path.splitext(f)
        if not file_extension == '.ini':
            f_list.append(f)    
    
    return sorted(f_list)
    
# return a list list all the .jpg files in 
def listdir_jpg(path):
    f_list = []
    for f in os.listdir(path):
        _, file_extension = os.path.splitext(f)
        if file_extension == '.jpg':
            f_list.append(f)
            
    return sorted(f_list)

# %% [markdown]
# ### Read in PV output

# %%
# Read in the pv output file
pv_output_all = pd.read_pickle(os.path.join(pv_data_folder))

# Obtain relevant data
pv_output_all = pv_output_all.loc[start_date:end_date]

# %% [markdown]
# ### Read in image paths

# %%
# Initialization: find all image file path
image_paths = []
all_times = []

years_list = listdir_noini(os.path.join(image_folder))
for year in years_list: # cycle through the years
    months_list = listdir_noini(os.path.join(image_folder,year))
    for month in months_list: # cycle through the months
        dates_list  = listdir_noini(os.path.join(image_folder,year,month))
        for date in dates_list: # cycle through each day
            image_filenames = listdir_jpg(os.path.join(image_folder,year,month,date))
            for filename in image_filenames:
                image_paths.append(os.path.join(image_folder,year,month,date,filename))
                all_times.append(dt.datetime.strptime(filename,image_name_format+'.jpg'))

# Only keep the one in the given time frame
image_paths = np.array(image_paths)
all_times = np.array(all_times)
print(all_times.shape)
in_range = (all_times>=start_date) & (all_times<end_date)
image_paths = image_paths[in_range]
all_times = all_times[in_range]
# Out:
# (508807,)

# %% [markdown]
# ### Load in each image, and save ones with valid PV_output

# %%
# Save images from snapshot folder to an npy file
# Designed for the high frequency (10s) dataset
number_images = len(image_paths)

all_images = np.ndarray([number_images] + output_img_shape,dtype='uint8')
pv_outputs = np.zeros(number_images)
validity_mask = np.zeros(number_images,dtype = bool)

# time counter
tic = time.process_time()

# Step through every snapshot, find if they have valid corresponding PV data

for i,image_path in enumerate(image_paths): # cycle through each file of the day
    # parse timestamp from image name
    curr_time = all_times[i]
    
    # test if there is corresponding data in PV data
    pv_idx = find_time_within_pdseries(pv_output_all.index,curr_time)
    if pv_idx is None:# if prediction ground truth not found
        print(curr_time,'has no PV record')
    else: 
        validity_mask[i] = 1
        frame = cv2.imread(os.path.join(image_path))
        # resizing the image to output_img_shape
        resizing_ratio = output_img_shape[0] / frame.shape[0]
        all_images[i] = cv2.resize(frame, None, fx=resizing_ratio, fy=resizing_ratio)
        pv_outputs[i] = pv_output_all.iloc[pv_idx]
    
    # prompt progress
    if i%100 == 0:
        print('processed {0} images/{1} images'.format(i,image_paths.size))
        if i%1000 == 0 and i>0:
            print('Expected finishing time:', dt.datetime.now()+
                  dt.timedelta(seconds = (time.process_time() - tic)*(image_paths.size/i-1)))
                                      
        
print('time_elapsed',time.process_time()-tic)
# Out:
# 2017-03-09 06:00:00 has no PV record
# processed 0 images/507963 images
# 2017-03-09 06:01:00 has no PV record
# 2017-03-09 06:02:00 has no PV record
# 2017-03-09 06:03:00 has no PV record
# 2017-03-09 06:04:00 has no PV record
# 2017-03-09 06:05:00 has no PV record
# 2017-03-09 06:06:00 has no PV record
# 2017-03-09 06:07:00 has no PV record
# 2017-03-09 06:08:00 has no PV record
# 2017-03-09 06:09:00 has no PV record
# 2017-03-09 06:10:00 has no PV record
# 2017-03-09 06:11:00 has no PV record
# 2017-03-09 06:12:00 has no PV record
# 2017-03-09 06:13:00 has no PV record
# 2017-03-09 06:14:00 has no PV record
# 2017-03-09 06:15:00 has no PV record
# 2017-03-09 06:16:00 has no PV record
# 2017-03-09 06:17:00 has no PV record
# 2017-03-09 06:18:00 has no PV record
# 2017-03-09 06:19:00 has no PV record
# 2017-03-09 06:20:00 has no PV record
# 2017-03-09 06:21:00 has no PV record
# 2017-03-09 06:22:00 has no PV record
# 2017-03-09 06:23:00 has no PV record
# 2017-03-09 06:24:00 has no PV record
# 2017-03-09 06:25:00 has no PV record
# 2017-03-09 06:26:00 has no PV record
# 2017-03-09 06:27:00 has no PV record
# 2017-03-09 06:28:00 has no PV record
# 2017-03-09 06:29:00 has no PV record
# 2017-03-09 06:30:00 has no PV record
# 2017-03-09 06:31:00 has no PV record
# 2017-03-09 06:32:00 has no PV record
# 2017-03-09 06:33:00 has no PV record
# 2017-03-09 06:34:00 has no PV record
# 2017-03-09 06:35:00 has no PV record
# 2017-03-09 06:36:00 has no PV record
# 2017-03-09 06:37:00 has no PV record
# 2017-03-09 06:38:00 has no PV record
# 2017-03-09 06:39:00 has no PV record
# 2017-03-09 06:40:00 has no PV record
# 2017-03-09 06:41:00 has no PV record
# 2017-03-09 06:42:00 has no PV record
# 2017-03-09 06:43:00 has no PV record
# 2017-03-09 06:44:00 has no PV record
# 2017-03-09 06:45:00 has no PV record
# 2017-03-09 06:46:00 has no PV record
# processed 100 images/507963 images
# processed 200 images/507963 images
# processed 300 images/507963 images
# processed 400 images/507963 images
# processed 500 images/507963 images
# processed 600 images/507963 images
# processed 700 images/507963 images
# 2017-03-09 18:04:40 has no PV record
# 2017-03-09 18:05:40 has no PV record
# 2017-03-09 18:06:40 has no PV record
# 2017-03-09 18:07:40 has no PV record
# 2017-03-09 18:08:40 has no PV record
# 2017-03-09 18:09:40 has no PV record
# 2017-03-09 18:10:40 has no PV record
# 2017-03-09 18:11:40 has no PV record
# 2017-03-09 18:12:20 has no PV record
# 2017-03-09 18:13:20 has no PV record
# 2017-03-09 18:14:20 has no PV record
# 2017-03-09 18:15:20 has no PV record
# 2017-03-09 18:16:20 has no PV record
# 2017-03-09 18:17:20 has no PV record
# 2017-03-09 18:18:20 has no PV record
# 2017-03-09 18:19:20 has no PV record
# 2017-03-09 18:20:20 has no PV record
# 2017-03-09 18:21:20 has no PV record
# 2017-03-09 18:22:20 has no PV record
# 2017-03-09 18:23:20 has no PV record
# 2017-03-09 18:24:20 has no PV record
# 2017-03-09 18:25:20 has no PV record
# 2017-03-09 18:26:20 has no PV record
# 2017-03-09 18:27:20 has no PV record
# 2017-03-09 18:28:20 has no PV record
# 2017-03-09 18:29:20 has no PV record
# 2017-03-09 18:30:20 has no PV record
# 2017-03-09 18:31:20 has no PV record
# 2017-03-09 18:32:20 has no PV record
# 2017-03-09 18:33:20 has no PV record
# 2017-03-09 18:34:20 has no PV record
# 2017-03-09 18:35:20 has no PV record
# 2017-03-09 18:36:20 has no PV record
# 2017-03-09 18:37:20 has no PV record
# 2017-03-09 18:38:20 has no PV record
# 2017-03-09 18:39:20 has no PV record
# 2017-03-09 18:40:20 has no PV record
# 2017-03-09 18:41:20 has no PV record
# 2017-03-09 18:42:20 has no PV record
# 2017-03-09 18:43:20 has no PV record
# 2017-03-09 18:44:20 has no PV record
# 2017-03-09 18:45:20 has no PV record
# 2017-03-09 18:46:20 has no PV record
# 2017-03-09 18:47:20 has no PV record
# 2017-03-09 18:47:50 has no PV record
# 2017-03-09 18:48:50 has no PV record
# 2017-03-09 18:49:50 has no PV record
# 2017-03-09 18:50:50 has no PV record
# 2017-03-09 18:51:50 has no PV record
# 2017-03-09 18:52:50 has no PV record
# 2017-03-09 18:53:50 has no PV record
# 2017-03-09 18:54:50 has no PV record
# 2017-03-09 18:55:50 has no PV record
# 2017-03-09 18:56:50 has no PV record
# 2017-03-09 18:57:50 has no PV record
# 2017-03-09 18:58:50 has no PV record
# 2017-03-09 18:59:50 has no PV record
# 2017-03-10 06:00:00 has no PV record
# 2017-03-10 06:01:00 has no PV record
# 2017-03-10 06:02:00 has no PV record
# 2017-03-10 06:03:00 has no PV record
# 2017-03-10 06:04:00 has no PV record
# 2017-03-10 06:05:00 has no PV record
# 2017-03-10 06:06:00 has no PV record
# 2017-03-10 06:07:00 has no PV record
# 2017-03-10 06:08:00 has no PV record
# 2017-03-10 06:08:30 has no PV record
# 2017-03-10 06:09:30 has no PV record
# 2017-03-10 06:10:30 has no PV record
# 2017-03-10 06:11:30 has no PV record
# 2017-03-10 06:12:30 has no PV record
# 2017-03-10 06:13:30 has no PV record
# 2017-03-10 06:14:30 has no PV record
# 2017-03-10 06:15:30 has no PV record
# 2017-03-10 06:16:30 has no PV record
# processed 800 images/507963 images
# 2017-03-10 06:17:30 has no PV record
# 2017-03-10 06:18:30 has no PV record
# 2017-03-10 06:19:30 has no PV record
# 2017-03-10 06:20:30 has no PV record
# 2017-03-10 06:21:30 has no PV record
# 2017-03-10 06:22:30 has no PV record
# 2017-03-10 06:23:30 has no PV record
# 2017-03-10 06:24:30 has no PV record
# 2017-03-10 06:25:30 has no PV record
# 2017-03-10 06:26:30 has no PV record
# 2017-03-10 06:27:30 has no PV record
# 2017-03-10 06:28:30 has no PV record
# 2017-03-10 06:29:30 has no PV record
# 2017-03-10 06:30:30 has no PV record
# 2017-03-10 06:31:30 has no PV record
# 2017-03-10 06:32:30 has no PV record
# 2017-03-10 06:33:30 has no PV record
# 2017-03-10 06:34:30 has no PV record
# 2017-03-10 06:35:30 has no PV record
# 2017-03-10 06:36:30 has no PV record
# 2017-03-10 06:37:30 has no PV record
# 2017-03-10 06:38:30 has no PV record
# 2017-03-10 06:39:30 has no PV record
# 2017-03-10 06:40:30 has no PV record
# 2017-03-10 06:41:30 has no PV record
# 2017-03-10 06:42:30 has no PV record
# 2017-03-10 06:43:30 has no PV record
# 2017-03-10 06:44:30 has no PV record
# 2017-03-10 06:45:30 has no PV record
# 2017-03-10 06:46:30 has no PV record
# 2017-03-10 06:47:30 has no PV record
# 2017-03-10 06:48:30 has no PV record
# 2017-03-10 06:49:30 has no PV record
# 2017-03-10 06:50:30 has no PV record
# 2017-03-10 06:51:30 has no PV record
# 2017-03-10 06:52:30 has no PV record
# 2017-03-10 06:53:30 has no PV record
# 2017-03-10 06:54:30 has no PV record
# 2017-03-10 06:55:30 has no PV record
# 2017-03-10 06:56:30 has no PV record
# 2017-03-10 06:57:30 has no PV record
# 2017-03-10 06:58:30 has no PV record
# 2017-03-10 06:59:30 has no PV record
# 2017-03-10 07:00:30 has no PV record
# 2017-03-10 07:01:30 has no PV record
# 2017-03-10 07:02:30 has no PV record
# 2017-03-10 07:03:30 has no PV record
# 2017-03-10 07:04:30 has no PV record
# 2017-03-10 07:05:30 has no PV record
# 2017-03-10 07:06:30 has no PV record
# 2017-03-10 07:07:30 has no PV record
# 2017-03-10 07:08:30 has no PV record
# 2017-03-10 07:09:30 has no PV record
# 2017-03-10 07:10:30 has no PV record
# 2017-03-10 07:11:30 has no PV record
# 2017-03-10 07:12:30 has no PV record
# 2017-03-10 07:13:30 has no PV record
# 2017-03-10 07:14:30 has no PV record
# 2017-03-10 07:15:30 has no PV record
# 2017-03-10 07:16:30 has no PV record
# 2017-03-10 07:17:30 has no PV record
# 2017-03-10 07:18:30 has no PV record
# 2017-03-10 07:19:30 has no PV record
# 2017-03-10 07:20:30 has no PV record
# 2017-03-10 07:21:30 has no PV record
# 2017-03-10 07:22:30 has no PV record
# 2017-03-10 07:23:30 has no PV record
# 2017-03-10 07:24:30 has no PV record
# 2017-03-10 07:25:30 has no PV record
# 2017-03-10 07:26:30 has no PV record
# 2017-03-10 07:27:30 has no PV record
# 2017-03-10 07:28:30 has no PV record
# 2017-03-10 07:29:30 has no PV record
# 2017-03-10 07:30:30 has no PV record
# 2017-03-10 07:31:30 has no PV record
# 2017-03-10 07:32:30 has no PV record
# 2017-03-10 07:33:30 has no PV record
# 2017-03-10 07:34:30 has no PV record
# 2017-03-10 07:35:30 has no PV record
# 2017-03-10 07:36:30 has no PV record
# 2017-03-10 07:37:30 has no PV record
# 2017-03-10 07:38:30 has no PV record
# 2017-03-10 07:39:30 has no PV record
# 2017-03-10 07:40:30 has no PV record
# 2017-03-10 07:41:30 has no PV record
# 2017-03-10 07:42:30 has no PV record
# 2017-03-10 07:43:30 has no PV record
# 2017-03-10 07:44:30 has no PV record
# 2017-03-10 07:45:30 has no PV record
# 2017-03-10 07:46:30 has no PV record
# 2017-03-10 07:47:20 has no PV record
# 2017-03-10 07:48:20 has no PV record
# 2017-03-10 07:49:20 has no PV record
# 2017-03-10 07:50:20 has no PV record
# 2017-03-10 07:51:20 has no PV record
# 2017-03-10 07:52:20 has no PV record
# 2017-03-10 07:53:20 has no PV record
# 2017-03-10 07:54:20 has no PV record
# 2017-03-10 07:55:20 has no PV record
# 2017-03-10 07:56:20 has no PV record
# processed 900 images/507963 images
# 2017-03-10 07:57:20 has no PV record
# 2017-03-10 07:58:20 has no PV record
# 2017-03-10 07:59:20 has no PV record
# 2017-03-10 08:00:20 has no PV record
# 2017-03-10 08:01:20 has no PV record
# 2017-03-10 08:02:20 has no PV record
# 2017-03-10 08:03:20 has no PV record
# 2017-03-10 08:04:20 has no PV record
# 2017-03-10 08:05:20 has no PV record
# 2017-03-10 08:06:20 has no PV record
# 2017-03-10 08:07:20 has no PV record
# 2017-03-10 08:08:20 has no PV record
# 2017-03-10 08:09:20 has no PV record
# 2017-03-10 08:10:20 has no PV record
# 2017-03-10 08:11:20 has no PV record
# 2017-03-10 08:12:20 has no PV record
# 2017-03-10 08:13:20 has no PV record
# 2017-03-10 08:14:20 has no PV record
# 2017-03-10 08:15:20 has no PV record
# 2017-03-10 08:16:20 has no PV record
# 2017-03-10 08:17:20 has no PV record
# 2017-03-10 08:18:20 has no PV record
# 2017-03-10 08:19:20 has no PV record
# 2017-03-10 08:20:20 has no PV record
# 2017-03-10 08:21:20 has no PV record
# 2017-03-10 08:22:20 has no PV record
# 2017-03-10 08:23:20 has no PV record
# 2017-03-10 08:24:20 has no PV record
# 2017-03-10 08:25:20 has no PV record
# 2017-03-10 08:26:20 has no PV record
# 2017-03-10 08:27:20 has no PV record
# 2017-03-10 08:28:20 has no PV record
# 2017-03-10 08:29:20 has no PV record
# 2017-03-10 08:30:20 has no PV record
# 2017-03-10 08:31:20 has no PV record
# 2017-03-10 08:32:20 has no PV record
# 2017-03-10 08:33:20 has no PV record
# 2017-03-10 08:34:20 has no PV record
# 2017-03-10 08:35:20 has no PV record
# 2017-03-10 08:36:20 has no PV record
# 2017-03-10 08:37:20 has no PV record
# 2017-03-10 08:38:20 has no PV record
# 2017-03-10 08:39:20 has no PV record
# 2017-03-10 08:40:20 has no PV record
# 2017-03-10 08:41:20 has no PV record
# 2017-03-10 08:42:20 has no PV record
# 2017-03-10 08:43:20 has no PV record
# 2017-03-10 08:44:20 has no PV record
# 2017-03-10 08:45:20 has no PV record
# 2017-03-10 08:46:20 has no PV record
# 2017-03-10 08:47:20 has no PV record
# 2017-03-10 08:48:20 has no PV record
# 2017-03-10 08:49:20 has no PV record
# 2017-03-10 08:50:20 has no PV record
# 2017-03-10 08:51:20 has no PV record
# 2017-03-10 08:52:20 has no PV record
# 2017-03-10 08:53:20 has no PV record
# 2017-03-10 08:54:20 has no PV record
# 2017-03-10 08:55:20 has no PV record
# 2017-03-10 08:56:20 has no PV record
# 2017-03-10 08:57:20 has no PV record
# 2017-03-10 08:58:20 has no PV record
# 2017-03-10 08:59:20 has no PV record
# 2017-03-10 09:00:20 has no PV record
# 2017-03-10 09:01:20 has no PV record
# 2017-03-10 09:02:20 has no PV record
# 2017-03-10 09:03:20 has no PV record
# 2017-03-10 09:04:20 has no PV record
# 2017-03-10 09:05:20 has no PV record
# 2017-03-10 09:06:20 has no PV record
# 2017-03-10 09:07:20 has no PV record
# 2017-03-10 09:08:20 has no PV record
# 2017-03-10 09:09:20 has no PV record
# 2017-03-10 09:10:20 has no PV record
# 2017-03-10 09:11:20 has no PV record
# 2017-03-10 09:12:20 has no PV record
# 2017-03-10 09:13:20 has no PV record
# 2017-03-10 09:14:20 has no PV record
# 2017-03-10 09:15:20 has no PV record
# 2017-03-10 09:16:20 has no PV record
# 2017-03-10 09:17:20 has no PV record
# 2017-03-10 09:18:20 has no PV record
# 2017-03-10 09:19:20 has no PV record
# 2017-03-10 09:20:20 has no PV record
# 2017-03-10 09:21:20 has no PV record
# 2017-03-10 09:22:20 has no PV record
# 2017-03-10 09:23:20 has no PV record
# 2017-03-10 09:24:20 has no PV record
# 2017-03-10 09:25:20 has no PV record
# 2017-03-10 09:26:20 has no PV record
# 2017-03-10 09:27:20 has no PV record
# 2017-03-10 09:28:20 has no PV record
# 2017-03-10 09:29:20 has no PV record
# 2017-03-10 09:30:20 has no PV record
# 2017-03-10 09:31:20 has no PV record
# 2017-03-10 09:32:20 has no PV record
# 2017-03-10 09:33:20 has no PV record
# 2017-03-10 09:34:20 has no PV record
# 2017-03-10 09:35:20 has no PV record
# 2017-03-10 09:36:20 has no PV record
# processed 1000 images/507963 images
# Expected finishing time: 2022-06-04 00:24:11.819379
# 2017-03-10 09:37:20 has no PV record
# 2017-03-10 09:38:20 has no PV record
# 2017-03-10 09:38:50 has no PV record
# 2017-03-10 09:39:50 has no PV record
# 2017-03-10 09:40:50 has no PV record
# 2017-03-10 09:41:50 has no PV record
# 2017-03-10 09:42:50 has no PV record
# 2017-03-10 09:43:50 has no PV record
# 2017-03-10 09:44:50 has no PV record
# 2017-03-10 09:45:50 has no PV record
# 2017-03-10 09:46:50 has no PV record
# 2017-03-10 09:47:50 has no PV record
# 2017-03-10 09:48:50 has no PV record
# 2017-03-10 09:49:50 has no PV record
# 2017-03-10 09:50:50 has no PV record
# 2017-03-10 09:51:50 has no PV record
# 2017-03-10 09:52:50 has no PV record
# 2017-03-10 09:53:50 has no PV record
# 2017-03-10 09:54:50 has no PV record
# 2017-03-10 09:55:50 has no PV record
# 2017-03-10 09:56:50 has no PV record
# 2017-03-10 09:57:50 has no PV record
# 2017-03-10 09:58:50 has no PV record
# 2017-03-10 09:59:50 has no PV record
# 2017-03-10 10:00:50 has no PV record
# 2017-03-10 10:01:50 has no PV record
# 2017-03-10 10:02:50 has no PV record
# 2017-03-10 10:03:50 has no PV record
# 2017-03-10 10:04:50 has no PV record
# 2017-03-10 10:05:50 has no PV record
# 2017-03-10 10:06:50 has no PV record
# 2017-03-10 10:07:50 has no PV record
# 2017-03-10 10:08:50 has no PV record
# 2017-03-10 10:09:50 has no PV record
# 2017-03-10 10:10:50 has no PV record
# 2017-03-10 10:11:50 has no PV record
# 2017-03-10 10:12:50 has no PV record
# 2017-03-10 10:13:50 has no PV record
# 2017-03-10 10:14:50 has no PV record
# 2017-03-10 10:15:50 has no PV record
# 2017-03-10 10:16:50 has no PV record
# 2017-03-10 10:17:50 has no PV record
# 2017-03-10 10:18:50 has no PV record
# 2017-03-10 10:19:50 has no PV record
# 2017-03-10 10:20:50 has no PV record
# 2017-03-10 10:21:50 has no PV record
# 2017-03-10 10:22:50 has no PV record
# 2017-03-10 10:23:50 has no PV record
# 2017-03-10 10:24:50 has no PV record
# 2017-03-10 10:25:50 has no PV record
# 2017-03-10 10:26:50 has no PV record
# 2017-03-10 10:27:50 has no PV record
# 2017-03-10 10:28:50 has no PV record
# 2017-03-10 10:29:50 has no PV record
# 2017-03-10 10:30:50 has no PV record
# 2017-03-10 10:31:50 has no PV record
# 2017-03-10 10:32:50 has no PV record
# 2017-03-10 10:33:50 has no PV record
# 2017-03-10 10:34:50 has no PV record
# 2017-03-10 10:35:50 has no PV record
# 2017-03-10 10:36:50 has no PV record
# 2017-03-10 10:37:50 has no PV record
# 2017-03-10 10:38:50 has no PV record
# 2017-03-10 10:39:50 has no PV record
# 2017-03-10 10:40:50 has no PV record
# 2017-03-10 10:41:50 has no PV record
# 2017-03-10 10:42:50 has no PV record
# 2017-03-10 10:43:50 has no PV record
# 2017-03-10 10:44:50 has no PV record
# 2017-03-10 10:45:50 has no PV record
# 2017-03-10 10:46:50 has no PV record
# 2017-03-10 10:47:50 has no PV record
# 2017-03-10 10:48:50 has no PV record
# 2017-03-10 10:49:50 has no PV record
# 2017-03-10 10:50:50 has no PV record
# 2017-03-10 10:51:50 has no PV record
# 2017-03-10 10:52:50 has no PV record
# 2017-03-10 10:53:50 has no PV record
# 2017-03-10 10:54:50 has no PV record
# 2017-03-10 10:55:50 has no PV record
# 2017-03-10 10:56:50 has no PV record
# 2017-03-10 10:57:50 has no PV record
# 2017-03-10 10:58:50 has no PV record
# 2017-03-10 10:59:50 has no PV record
# 2017-03-10 11:00:50 has no PV record
# 2017-03-10 11:01:50 has no PV record
# 2017-03-10 11:02:50 has no PV record
# 2017-03-10 11:03:50 has no PV record
# 2017-03-10 11:04:50 has no PV record
# 2017-03-10 11:05:50 has no PV record
# 2017-03-10 11:06:50 has no PV record
# 2017-03-10 11:07:50 has no PV record
# 2017-03-10 11:08:50 has no PV record
# 2017-03-10 11:09:50 has no PV record
# 2017-03-10 11:10:50 has no PV record
# 2017-03-10 11:11:50 has no PV record
# 2017-03-10 11:12:50 has no PV record
# 2017-03-10 11:13:50 has no PV record
# 2017-03-10 11:14:50 has no PV record
# 2017-03-10 11:15:50 has no PV record
# processed 1100 images/507963 images
# 2017-03-10 11:16:50 has no PV record
# 2017-03-10 11:17:40 has no PV record
# 2017-03-10 11:18:40 has no PV record
# 2017-03-10 11:19:40 has no PV record
# 2017-03-10 11:20:40 has no PV record
# 2017-03-10 11:21:40 has no PV record
# 2017-03-10 11:22:40 has no PV record
# 2017-03-10 11:23:40 has no PV record
# 2017-03-10 11:24:40 has no PV record
# 2017-03-10 11:25:40 has no PV record
# 2017-03-10 11:26:40 has no PV record
# 2017-03-10 11:27:40 has no PV record
# 2017-03-10 11:28:40 has no PV record
# 2017-03-10 11:29:40 has no PV record
# 2017-03-10 11:30:40 has no PV record
# 2017-03-10 11:31:40 has no PV record
# 2017-03-10 11:32:40 has no PV record
# 2017-03-10 11:33:40 has no PV record
# 2017-03-10 11:34:40 has no PV record
# 2017-03-10 11:35:40 has no PV record
# 2017-03-10 11:36:40 has no PV record
# 2017-03-10 11:37:40 has no PV record
# 2017-03-10 11:38:40 has no PV record
# 2017-03-10 11:39:40 has no PV record
# 2017-03-10 11:40:40 has no PV record
# 2017-03-10 11:41:40 has no PV record
# 2017-03-10 11:42:40 has no PV record
# 2017-03-10 11:43:40 has no PV record
# 2017-03-10 11:44:40 has no PV record
# 2017-03-10 11:45:40 has no PV record
# 2017-03-10 11:46:40 has no PV record
# 2017-03-10 11:47:40 has no PV record
# 2017-03-10 11:48:40 has no PV record
# 2017-03-10 11:49:40 has no PV record
# 2017-03-10 11:50:40 has no PV record
# 2017-03-10 11:51:40 has no PV record
# 2017-03-10 11:52:40 has no PV record
# 2017-03-10 11:53:40 has no PV record
# 2017-03-10 11:54:40 has no PV record
# 2017-03-10 11:55:40 has no PV record
# 2017-03-10 11:56:40 has no PV record
# 2017-03-10 11:57:40 has no PV record
# 2017-03-10 11:58:40 has no PV record
# 2017-03-10 11:59:40 has no PV record
# 2017-03-10 12:00:40 has no PV record
# 2017-03-10 12:01:40 has no PV record
# 2017-03-10 12:02:40 has no PV record
# 2017-03-10 12:03:40 has no PV record
# 2017-03-10 12:04:40 has no PV record
# 2017-03-10 12:05:40 has no PV record
# 2017-03-10 12:06:40 has no PV record
# 2017-03-10 12:07:40 has no PV record
# 2017-03-10 12:08:40 has no PV record
# 2017-03-10 12:09:40 has no PV record
# 2017-03-10 12:10:40 has no PV record
# 2017-03-10 12:11:40 has no PV record
# 2017-03-10 12:12:40 has no PV record
# 2017-03-10 12:13:40 has no PV record
# 2017-03-10 12:14:40 has no PV record
# 2017-03-10 12:15:40 has no PV record
# 2017-03-10 12:16:40 has no PV record
# 2017-03-10 12:17:40 has no PV record
# 2017-03-10 12:18:40 has no PV record
# 2017-03-10 12:19:40 has no PV record
# 2017-03-10 12:20:40 has no PV record
# 2017-03-10 12:21:40 has no PV record
# 2017-03-10 12:22:40 has no PV record
# 2017-03-10 12:23:40 has no PV record
# 2017-03-10 12:24:40 has no PV record
# 2017-03-10 12:25:40 has no PV record
# 2017-03-10 12:26:40 has no PV record
# 2017-03-10 12:27:40 has no PV record
# 2017-03-10 12:28:40 has no PV record
# 2017-03-10 12:29:40 has no PV record
# 2017-03-10 12:30:40 has no PV record
# 2017-03-10 12:31:40 has no PV record
# 2017-03-10 12:32:40 has no PV record
# 2017-03-10 12:33:10 has no PV record
# 2017-03-10 12:34:10 has no PV record
# 2017-03-10 12:35:10 has no PV record
# 2017-03-10 12:36:10 has no PV record
# 2017-03-10 12:37:10 has no PV record
# 2017-03-10 12:38:10 has no PV record
# 2017-03-10 12:39:10 has no PV record
# 2017-03-10 12:40:10 has no PV record
# 2017-03-10 12:41:10 has no PV record
# 2017-03-10 12:42:10 has no PV record
# 2017-03-10 12:43:10 has no PV record
# 2017-03-10 12:44:10 has no PV record
# 2017-03-10 12:45:10 has no PV record
# 2017-03-10 12:46:10 has no PV record
# 2017-03-10 12:47:10 has no PV record
# 2017-03-10 12:48:10 has no PV record
# 2017-03-10 12:49:10 has no PV record
# 2017-03-10 12:50:10 has no PV record
# 2017-03-10 12:51:10 has no PV record
# 2017-03-10 12:52:10 has no PV record
# 2017-03-10 12:53:10 has no PV record
# 2017-03-10 12:54:10 has no PV record
# 2017-03-10 12:55:10 has no PV record
# processed 1200 images/507963 images
# 2017-03-10 12:56:10 has no PV record
# 2017-03-10 12:57:10 has no PV record
# 2017-03-10 12:58:10 has no PV record
# 2017-03-10 12:59:10 has no PV record
# 2017-03-10 13:00:10 has no PV record
# 2017-03-10 13:01:10 has no PV record
# 2017-03-10 13:02:10 has no PV record
# 2017-03-10 13:03:10 has no PV record
# 2017-03-10 13:04:10 has no PV record
# 2017-03-10 13:05:10 has no PV record
# 2017-03-10 13:06:10 has no PV record
# 2017-03-10 13:07:10 has no PV record
# 2017-03-10 13:08:10 has no PV record
# 2017-03-10 13:09:10 has no PV record
# 2017-03-10 13:10:10 has no PV record
# 2017-03-10 13:11:10 has no PV record
# 2017-03-10 13:12:10 has no PV record
# 2017-03-10 13:13:10 has no PV record
# 2017-03-10 13:14:10 has no PV record
# 2017-03-10 13:15:10 has no PV record
# 2017-03-10 13:16:10 has no PV record
# 2017-03-10 13:17:10 has no PV record
# 2017-03-10 13:18:10 has no PV record
# 2017-03-10 13:19:10 has no PV record
# 2017-03-10 13:20:10 has no PV record
# 2017-03-10 13:21:10 has no PV record
# 2017-03-10 13:22:10 has no PV record
# 2017-03-10 13:23:10 has no PV record
# 2017-03-10 13:24:10 has no PV record
# 2017-03-10 13:25:10 has no PV record
# 2017-03-10 13:26:10 has no PV record
# 2017-03-10 13:27:10 has no PV record
# 2017-03-10 13:28:10 has no PV record
# 2017-03-10 13:29:10 has no PV record
# 2017-03-10 13:30:10 has no PV record
# 2017-03-10 13:31:10 has no PV record
# 2017-03-10 13:32:10 has no PV record
# 2017-03-10 13:33:10 has no PV record
# 2017-03-10 13:34:10 has no PV record
# 2017-03-10 13:35:10 has no PV record
# 2017-03-10 13:36:10 has no PV record
# 2017-03-10 13:37:10 has no PV record
# 2017-03-10 13:38:10 has no PV record
# 2017-03-10 13:39:10 has no PV record
# 2017-03-10 13:40:10 has no PV record
# 2017-03-10 13:41:10 has no PV record
# 2017-03-10 13:42:10 has no PV record
# 2017-03-10 13:43:10 has no PV record
# 2017-03-10 13:44:10 has no PV record
# 2017-03-10 13:45:10 has no PV record
# 2017-03-10 13:46:10 has no PV record
# 2017-03-10 13:47:10 has no PV record
# 2017-03-10 13:48:10 has no PV record
# 2017-03-10 13:49:10 has no PV record
# 2017-03-10 13:50:10 has no PV record
# 2017-03-10 13:51:10 has no PV record
# 2017-03-10 13:52:10 has no PV record
# 2017-03-10 13:53:10 has no PV record
# 2017-03-10 13:54:10 has no PV record
# 2017-03-10 13:55:10 has no PV record
# 2017-03-10 13:56:10 has no PV record
# 2017-03-10 13:57:10 has no PV record
# 2017-03-10 13:58:10 has no PV record
# 2017-03-10 13:59:10 has no PV record
# 2017-03-10 14:00:10 has no PV record
# 2017-03-10 14:01:10 has no PV record
# 2017-03-10 14:02:10 has no PV record
# 2017-03-10 14:03:10 has no PV record
# 2017-03-10 14:04:10 has no PV record
# 2017-03-10 14:05:10 has no PV record
# 2017-03-10 14:06:10 has no PV record
# 2017-03-10 14:07:10 has no PV record
# 2017-03-10 14:08:10 has no PV record
# 2017-03-10 14:09:10 has no PV record
# 2017-03-10 14:10:10 has no PV record
# 2017-03-10 14:11:10 has no PV record
# 2017-03-10 14:12:10 has no PV record
# 2017-03-10 14:13:10 has no PV record
# 2017-03-10 14:14:10 has no PV record
# 2017-03-10 14:15:10 has no PV record
# 2017-03-10 14:16:10 has no PV record
# 2017-03-10 14:17:10 has no PV record
# 2017-03-10 14:18:10 has no PV record
# 2017-03-10 14:19:10 has no PV record
# 2017-03-10 14:20:10 has no PV record
# 2017-03-10 14:21:10 has no PV record
# 2017-03-10 14:21:20 has no PV record
# 2017-03-10 14:22:20 has no PV record
# 2017-03-10 14:23:20 has no PV record
# 2017-03-10 14:24:20 has no PV record
# 2017-03-10 14:25:20 has no PV record
# 2017-03-10 14:26:20 has no PV record
# 2017-03-10 14:27:20 has no PV record
# 2017-03-10 14:28:20 has no PV record
# 2017-03-10 14:29:20 has no PV record
# 2017-03-10 14:30:20 has no PV record
# 2017-03-10 14:31:20 has no PV record
# 2017-03-10 14:32:20 has no PV record
# 2017-03-10 14:33:20 has no PV record
# 2017-03-10 14:34:20 has no PV record
# processed 1300 images/507963 images
# 2017-03-10 14:35:20 has no PV record
# 2017-03-10 14:36:20 has no PV record
# 2017-03-10 14:37:20 has no PV record
# 2017-03-10 14:38:20 has no PV record
# 2017-03-10 14:39:20 has no PV record
# 2017-03-10 14:40:20 has no PV record
# 2017-03-10 14:41:20 has no PV record
# 2017-03-10 14:42:20 has no PV record
# 2017-03-10 14:43:20 has no PV record
# 2017-03-10 14:44:20 has no PV record
# 2017-03-10 14:45:20 has no PV record
# 2017-03-10 14:46:20 has no PV record
# 2017-03-10 14:47:20 has no PV record
# 2017-03-10 14:48:20 has no PV record
# 2017-03-10 14:49:20 has no PV record
# 2017-03-10 14:50:20 has no PV record
# 2017-03-10 14:51:20 has no PV record
# 2017-03-10 14:52:20 has no PV record
# 2017-03-10 14:53:20 has no PV record
# 2017-03-10 14:54:20 has no PV record
# 2017-03-10 14:55:20 has no PV record
# 2017-03-10 14:56:20 has no PV record
# 2017-03-10 14:57:20 has no PV record
# 2017-03-10 14:58:20 has no PV record
# 2017-03-10 14:59:20 has no PV record
# 2017-03-10 15:00:20 has no PV record
# 2017-03-10 15:01:20 has no PV record
# 2017-03-10 15:02:20 has no PV record
# 2017-03-10 15:03:20 has no PV record
# 2017-03-10 15:04:20 has no PV record
# 2017-03-10 15:05:20 has no PV record
# 2017-03-10 15:06:20 has no PV record
# 2017-03-10 15:07:20 has no PV record
# 2017-03-10 15:08:20 has no PV record
# 2017-03-10 15:09:20 has no PV record
# 2017-03-10 15:10:20 has no PV record
# 2017-03-10 15:11:20 has no PV record
# 2017-03-10 15:12:20 has no PV record
# 2017-03-10 15:13:20 has no PV record
# 2017-03-10 15:14:20 has no PV record
# 2017-03-10 15:15:20 has no PV record
# 2017-03-10 15:16:20 has no PV record
# 2017-03-10 15:17:20 has no PV record
# 2017-03-10 15:18:20 has no PV record
# 2017-03-10 15:19:20 has no PV record
# 2017-03-10 15:20:20 has no PV record
# 2017-03-10 15:21:20 has no PV record
# 2017-03-10 15:22:20 has no PV record
# 2017-03-10 15:23:20 has no PV record
# 2017-03-10 15:24:20 has no PV record
# 2017-03-10 15:25:20 has no PV record
# 2017-03-10 15:26:20 has no PV record
# 2017-03-10 15:26:40 has no PV record
# 2017-03-10 15:27:40 has no PV record
# 2017-03-10 15:28:40 has no PV record
# 2017-03-10 15:29:40 has no PV record
# 2017-03-10 15:30:40 has no PV record
# 2017-03-10 15:31:40 has no PV record
# 2017-03-10 15:32:40 has no PV record
# 2017-03-10 15:33:40 has no PV record
# 2017-03-10 15:34:40 has no PV record
# 2017-03-10 15:35:40 has no PV record
# 2017-03-10 15:36:40 has no PV record
# 2017-03-10 15:37:40 has no PV record
# 2017-03-10 15:38:40 has no PV record
# 2017-03-10 15:39:40 has no PV record
# 2017-03-10 15:40:40 has no PV record
# 2017-03-10 15:41:40 has no PV record
# 2017-03-10 15:42:40 has no PV record
# 2017-03-10 15:43:40 has no PV record
# 2017-03-10 15:44:40 has no PV record
# 2017-03-10 15:45:40 has no PV record
# 2017-03-10 15:46:40 has no PV record
# 2017-03-10 15:47:40 has no PV record
# 2017-03-10 15:48:40 has no PV record
# 2017-03-10 15:49:40 has no PV record
# 2017-03-10 15:50:40 has no PV record
# 2017-03-10 15:51:40 has no PV record
# 2017-03-10 15:52:40 has no PV record
# 2017-03-10 15:53:40 has no PV record
# 2017-03-10 15:54:40 has no PV record
# 2017-03-10 15:55:40 has no PV record
# 2017-03-10 15:56:40 has no PV record
# 2017-03-10 15:57:40 has no PV record
# 2017-03-10 15:58:40 has no PV record
# 2017-03-10 15:59:40 has no PV record
# 2017-03-10 16:00:40 has no PV record
# 2017-03-10 16:01:40 has no PV record
# 2017-03-10 16:02:40 has no PV record
# 2017-03-10 16:03:40 has no PV record
# 2017-03-10 16:04:40 has no PV record
# 2017-03-10 16:05:40 has no PV record
# 2017-03-10 16:06:40 has no PV record
# 2017-03-10 16:07:40 has no PV record
# 2017-03-10 16:08:40 has no PV record
# 2017-03-10 16:09:40 has no PV record
# 2017-03-10 16:10:40 has no PV record
# 2017-03-10 16:11:40 has no PV record
# 2017-03-10 16:12:40 has no PV record
# 2017-03-10 16:13:40 has no PV record
# processed 1400 images/507963 images
# 2017-03-10 16:14:40 has no PV record
# 2017-03-10 16:15:40 has no PV record
# 2017-03-10 16:16:40 has no PV record
# 2017-03-10 16:17:40 has no PV record
# 2017-03-10 16:18:40 has no PV record
# 2017-03-10 16:19:40 has no PV record
# 2017-03-10 16:20:40 has no PV record
# 2017-03-10 16:21:40 has no PV record
# 2017-03-10 16:22:40 has no PV record
# 2017-03-10 16:23:40 has no PV record
# 2017-03-10 16:24:40 has no PV record
# 2017-03-10 16:25:40 has no PV record
# 2017-03-10 16:26:40 has no PV record
# 2017-03-10 16:27:40 has no PV record
# 2017-03-10 16:28:40 has no PV record
# 2017-03-10 16:29:40 has no PV record
# 2017-03-10 16:30:40 has no PV record
# 2017-03-10 16:31:40 has no PV record
# 2017-03-10 16:32:40 has no PV record
# 2017-03-10 16:33:40 has no PV record
# 2017-03-10 16:34:40 has no PV record
# 2017-03-10 16:35:40 has no PV record
# 2017-03-10 16:36:40 has no PV record
# 2017-03-10 16:37:40 has no PV record
# 2017-03-10 16:38:40 has no PV record
# 2017-03-10 16:39:40 has no PV record
# 2017-03-10 16:40:40 has no PV record
# 2017-03-10 16:41:40 has no PV record
# 2017-03-10 16:42:40 has no PV record
# 2017-03-10 16:43:40 has no PV record
# 2017-03-10 16:44:40 has no PV record
# 2017-03-10 16:45:40 has no PV record
# 2017-03-10 16:46:10 has no PV record
# 2017-03-10 16:47:10 has no PV record
# 2017-03-10 16:48:10 has no PV record
# 2017-03-10 16:49:10 has no PV record
# 2017-03-10 16:50:10 has no PV record
# 2017-03-10 16:51:10 has no PV record
# 2017-03-10 16:52:10 has no PV record
# 2017-03-10 16:53:10 has no PV record
# 2017-03-10 16:54:10 has no PV record
# 2017-03-10 16:55:10 has no PV record
# 2017-03-10 16:56:10 has no PV record
# 2017-03-10 16:57:10 has no PV record
# 2017-03-10 16:58:10 has no PV record
# 2017-03-10 16:59:10 has no PV record
# 2017-03-10 17:00:10 has no PV record
# 2017-03-10 17:01:10 has no PV record
# 2017-03-10 17:02:10 has no PV record
# 2017-03-10 17:03:10 has no PV record
# 2017-03-10 17:04:10 has no PV record
# 2017-03-10 17:05:10 has no PV record
# 2017-03-10 17:06:10 has no PV record
# 2017-03-10 17:07:10 has no PV record
# 2017-03-10 17:08:10 has no PV record
# 2017-03-10 17:09:10 has no PV record
# 2017-03-10 17:10:10 has no PV record
# 2017-03-10 17:11:10 has no PV record
# 2017-03-10 17:12:10 has no PV record
# 2017-03-10 17:13:10 has no PV record
# 2017-03-10 17:14:10 has no PV record
# 2017-03-10 17:15:10 has no PV record
# 2017-03-10 17:16:10 has no PV record
# 2017-03-10 17:17:10 has no PV record
# 2017-03-10 17:18:10 has no PV record
# 2017-03-10 17:19:10 has no PV record
# 2017-03-10 17:20:10 has no PV record
# 2017-03-10 17:21:10 has no PV record
# 2017-03-10 17:22:10 has no PV record
# 2017-03-10 17:23:10 has no PV record
# 2017-03-10 17:24:10 has no PV record
# 2017-03-10 17:25:10 has no PV record
# 2017-03-10 17:26:10 has no PV record
# 2017-03-10 17:27:10 has no PV record
# 2017-03-10 17:28:10 has no PV record
# 2017-03-10 17:29:10 has no PV record
# 2017-03-10 17:30:10 has no PV record
# 2017-03-10 17:31:10 has no PV record
# 2017-03-10 17:32:10 has no PV record
# 2017-03-10 17:33:10 has no PV record
# 2017-03-10 17:34:10 has no PV record
# 2017-03-10 17:35:10 has no PV record
# 2017-03-10 17:36:10 has no PV record
# 2017-03-10 17:37:10 has no PV record
# 2017-03-10 17:38:10 has no PV record
# 2017-03-10 17:39:10 has no PV record
# 2017-03-10 17:40:10 has no PV record
# 2017-03-10 17:41:10 has no PV record
# 2017-03-10 17:42:10 has no PV record
# 2017-03-10 17:43:10 has no PV record
# 2017-03-10 17:44:10 has no PV record
# 2017-03-10 17:45:10 has no PV record
# 2017-03-10 17:46:10 has no PV record
# 2017-03-10 17:47:10 has no PV record
# 2017-03-10 17:48:10 has no PV record
# 2017-03-10 17:49:10 has no PV record
# 2017-03-10 17:50:10 has no PV record
# 2017-03-10 17:51:10 has no PV record
# 2017-03-10 17:52:10 has no PV record
# 2017-03-10 17:53:10 has no PV record
# processed 1500 images/507963 images
# 2017-03-10 17:54:10 has no PV record
# 2017-03-10 17:55:10 has no PV record
# 2017-03-10 17:56:10 has no PV record
# 2017-03-10 17:57:10 has no PV record
# 2017-03-10 17:58:10 has no PV record
# 2017-03-10 17:59:10 has no PV record
# 2017-03-10 18:00:10 has no PV record
# 2017-03-10 18:01:10 has no PV record
# 2017-03-10 18:02:10 has no PV record
# 2017-03-10 18:03:10 has no PV record
# 2017-03-10 18:04:10 has no PV record
# 2017-03-10 18:05:10 has no PV record
# 2017-03-10 18:06:10 has no PV record
# 2017-03-10 18:07:10 has no PV record
# 2017-03-10 18:08:10 has no PV record
# 2017-03-10 18:09:10 has no PV record
# 2017-03-10 18:10:10 has no PV record
# 2017-03-10 18:11:10 has no PV record
# 2017-03-10 18:12:10 has no PV record
# 2017-03-10 18:13:10 has no PV record
# 2017-03-10 18:14:10 has no PV record
# 2017-03-10 18:15:10 has no PV record
# 2017-03-10 18:16:10 has no PV record
# 2017-03-10 18:17:10 has no PV record
# 2017-03-10 18:18:10 has no PV record
# 2017-03-10 18:19:10 has no PV record
# 2017-03-10 18:19:20 has no PV record
# 2017-03-10 18:20:20 has no PV record
# 2017-03-10 18:21:20 has no PV record
# 2017-03-10 18:22:20 has no PV record
# 2017-03-10 18:23:20 has no PV record
# 2017-03-10 18:24:20 has no PV record
# 2017-03-10 18:25:20 has no PV record
# 2017-03-10 18:26:20 has no PV record
# 2017-03-10 18:27:20 has no PV record
# 2017-03-10 18:28:20 has no PV record
# 2017-03-10 18:29:20 has no PV record
# 2017-03-10 18:30:20 has no PV record
# 2017-03-10 18:31:20 has no PV record
# 2017-03-10 18:32:20 has no PV record
# 2017-03-10 18:33:20 has no PV record
# 2017-03-10 18:34:20 has no PV record
# 2017-03-10 18:35:20 has no PV record
# 2017-03-10 18:36:20 has no PV record
# 2017-03-10 18:37:20 has no PV record
# 2017-03-10 18:38:20 has no PV record
# 2017-03-10 18:39:20 has no PV record
# 2017-03-10 18:40:20 has no PV record
# 2017-03-10 18:41:20 has no PV record
# 2017-03-10 18:42:20 has no PV record
# 2017-03-10 18:43:20 has no PV record
# 2017-03-10 18:44:20 has no PV record
# 2017-03-10 18:45:20 has no PV record
# 2017-03-10 18:46:20 has no PV record
# 2017-03-10 18:47:20 has no PV record
# 2017-03-10 18:48:20 has no PV record
# 2017-03-10 18:49:20 has no PV record
# 2017-03-10 18:50:20 has no PV record
# 2017-03-10 18:51:00 has no PV record
# 2017-03-10 18:52:00 has no PV record
# 2017-03-10 18:53:00 has no PV record
# 2017-03-10 18:54:00 has no PV record
# 2017-03-10 18:55:00 has no PV record
# 2017-03-10 18:56:00 has no PV record
# 2017-03-10 18:57:00 has no PV record
# 2017-03-10 18:58:00 has no PV record
# 2017-03-10 18:59:00 has no PV record
# 2017-03-10 19:00:00 has no PV record
# 2017-03-11 06:00:00 has no PV record
# 2017-03-11 06:01:00 has no PV record
# 2017-03-11 06:02:00 has no PV record
# 2017-03-11 06:03:00 has no PV record
# 2017-03-11 06:04:00 has no PV record
# 2017-03-11 06:05:00 has no PV record
# 2017-03-11 06:06:00 has no PV record
# 2017-03-11 06:07:00 has no PV record
# 2017-03-11 06:08:00 has no PV record
# 2017-03-11 06:09:00 has no PV record
# 2017-03-11 06:10:00 has no PV record
# 2017-03-11 06:11:00 has no PV record
# 2017-03-11 06:12:00 has no PV record
# 2017-03-11 06:13:00 has no PV record
# 2017-03-11 06:14:00 has no PV record
# 2017-03-11 06:15:00 has no PV record
# 2017-03-11 06:16:00 has no PV record
# 2017-03-11 06:17:00 has no PV record
# 2017-03-11 06:18:00 has no PV record
# 2017-03-11 06:19:00 has no PV record
# 2017-03-11 06:20:00 has no PV record
# 2017-03-11 06:21:00 has no PV record
# 2017-03-11 06:22:00 has no PV record
# 2017-03-11 06:23:00 has no PV record
# 2017-03-11 06:24:00 has no PV record
# 2017-03-11 06:25:00 has no PV record
# 2017-03-11 06:26:00 has no PV record
# 2017-03-11 06:27:00 has no PV record
# 2017-03-11 06:28:00 has no PV record
# 2017-03-11 06:29:00 has no PV record
# 2017-03-11 06:30:00 has no PV record
# 2017-03-11 06:31:00 has no PV record
# processed 1600 images/507963 images
# 2017-03-11 06:32:00 has no PV record
# 2017-03-11 06:33:00 has no PV record
# 2017-03-11 06:34:00 has no PV record
# 2017-03-11 06:35:00 has no PV record
# 2017-03-11 06:36:00 has no PV record
# 2017-03-11 06:37:00 has no PV record
# 2017-03-11 06:38:00 has no PV record
# 2017-03-11 06:39:00 has no PV record
# 2017-03-11 06:40:00 has no PV record
# 2017-03-11 06:41:00 has no PV record
# 2017-03-11 06:42:00 has no PV record
# 2017-03-11 06:43:00 has no PV record
# 2017-03-11 06:44:00 has no PV record
# 2017-03-11 06:45:00 has no PV record
# 2017-03-11 06:46:00 has no PV record
# 2017-03-11 06:47:00 has no PV record
# 2017-03-11 06:48:00 has no PV record
# 2017-03-11 06:49:00 has no PV record
# 2017-03-11 06:50:00 has no PV record
# 2017-03-11 06:51:00 has no PV record
# 2017-03-11 06:52:00 has no PV record
# 2017-03-11 06:53:00 has no PV record
# 2017-03-11 06:54:00 has no PV record
# 2017-03-11 06:55:00 has no PV record
# 2017-03-11 06:56:00 has no PV record
# 2017-03-11 06:57:00 has no PV record
# 2017-03-11 06:58:00 has no PV record
# 2017-03-11 06:59:00 has no PV record
# 2017-03-11 07:00:00 has no PV record
# 2017-03-11 07:01:00 has no PV record
# 2017-03-11 07:02:00 has no PV record
# 2017-03-11 07:03:00 has no PV record
# 2017-03-11 07:04:00 has no PV record
# 2017-03-11 07:05:00 has no PV record
# 2017-03-11 07:06:00 has no PV record
# 2017-03-11 07:07:00 has no PV record
# 2017-03-11 07:08:00 has no PV record
# 2017-03-11 07:09:00 has no PV record
# 2017-03-11 07:10:00 has no PV record
# 2017-03-11 07:11:00 has no PV record
# 2017-03-11 07:12:00 has no PV record
# 2017-03-11 07:13:00 has no PV record
# 2017-03-11 07:14:00 has no PV record
# 2017-03-11 07:15:00 has no PV record
# 2017-03-11 07:16:00 has no PV record
# 2017-03-11 07:17:00 has no PV record
# 2017-03-11 07:18:00 has no PV record
# 2017-03-11 07:19:00 has no PV record
# 2017-03-11 07:20:00 has no PV record
# 2017-03-11 07:21:00 has no PV record
# 2017-03-11 07:22:00 has no PV record
# 2017-03-11 07:23:00 has no PV record
# 2017-03-11 07:24:00 has no PV record
# 2017-03-11 07:25:00 has no PV record
# 2017-03-11 07:26:00 has no PV record
# 2017-03-11 07:27:00 has no PV record
# 2017-03-11 07:28:00 has no PV record
# 2017-03-11 07:29:00 has no PV record
# 2017-03-11 07:30:00 has no PV record
# 2017-03-11 07:31:00 has no PV record
# 2017-03-11 07:32:00 has no PV record
# 2017-03-11 07:33:00 has no PV record
# 2017-03-11 07:34:00 has no PV record
# 2017-03-11 07:35:00 has no PV record
# 2017-03-11 07:36:00 has no PV record
# 2017-03-11 07:37:00 has no PV record
# 2017-03-11 07:38:00 has no PV record
# 2017-03-11 07:39:00 has no PV record
# 2017-03-11 07:40:00 has no PV record
# 2017-03-11 07:41:00 has no PV record
# 2017-03-11 07:42:00 has no PV record
# 2017-03-11 07:43:00 has no PV record
# 2017-03-11 07:44:00 has no PV record
# 2017-03-11 07:45:00 has no PV record
# 2017-03-11 07:46:00 has no PV record
# 2017-03-11 07:47:00 has no PV record
# 2017-03-11 07:48:00 has no PV record
# 2017-03-11 07:49:00 has no PV record
# 2017-03-11 07:50:00 has no PV record
# 2017-03-11 07:51:00 has no PV record
# 2017-03-11 07:52:00 has no PV record
# 2017-03-11 07:53:00 has no PV record
# 2017-03-11 07:54:00 has no PV record
# 2017-03-11 07:55:00 has no PV record
# 2017-03-11 07:56:00 has no PV record
# 2017-03-11 07:57:00 has no PV record
# 2017-03-11 07:58:00 has no PV record
# 2017-03-11 07:59:00 has no PV record
# 2017-03-11 08:00:00 has no PV record
# 2017-03-11 08:01:00 has no PV record
# 2017-03-11 08:02:00 has no PV record
# 2017-03-11 08:03:00 has no PV record
# 2017-03-11 08:04:00 has no PV record
# 2017-03-11 08:05:00 has no PV record
# 2017-03-11 08:06:00 has no PV record
# 2017-03-11 08:07:00 has no PV record
# 2017-03-11 08:08:00 has no PV record
# 2017-03-11 08:09:00 has no PV record
# 2017-03-11 08:10:00 has no PV record
# 2017-03-11 08:11:00 has no PV record
# processed 1700 images/507963 images
# 2017-03-11 08:12:00 has no PV record
# 2017-03-11 08:13:00 has no PV record
# 2017-03-11 08:14:00 has no PV record
# 2017-03-11 08:15:00 has no PV record
# 2017-03-11 08:16:00 has no PV record
# 2017-03-11 08:17:00 has no PV record
# 2017-03-11 08:18:00 has no PV record
# 2017-03-11 08:19:00 has no PV record
# 2017-03-11 08:20:00 has no PV record
# 2017-03-11 08:21:00 has no PV record
# 2017-03-11 08:22:00 has no PV record
# 2017-03-11 08:23:00 has no PV record
# 2017-03-11 08:24:00 has no PV record
# 2017-03-11 08:25:00 has no PV record
# 2017-03-11 08:26:00 has no PV record
# 2017-03-11 08:27:00 has no PV record
# 2017-03-11 08:28:00 has no PV record
# 2017-03-11 08:29:00 has no PV record
# 2017-03-11 08:30:00 has no PV record
# 2017-03-11 08:31:00 has no PV record
# 2017-03-11 08:32:00 has no PV record
# 2017-03-11 08:33:00 has no PV record
# 2017-03-11 08:34:00 has no PV record
# 2017-03-11 08:35:00 has no PV record
# 2017-03-11 08:36:00 has no PV record
# 2017-03-11 08:37:00 has no PV record
# 2017-03-11 08:38:00 has no PV record
# 2017-03-11 08:39:00 has no PV record
# 2017-03-11 08:40:00 has no PV record
# 2017-03-11 08:41:00 has no PV record
# 2017-03-11 08:42:00 has no PV record
# 2017-03-11 08:43:00 has no PV record
# 2017-03-11 08:44:00 has no PV record
# 2017-03-11 08:45:00 has no PV record
# 2017-03-11 08:46:00 has no PV record
# 2017-03-11 08:47:00 has no PV record
# 2017-03-11 08:48:00 has no PV record
# 2017-03-11 08:49:00 has no PV record
# 2017-03-11 08:50:00 has no PV record
# 2017-03-11 08:51:00 has no PV record
# 2017-03-11 08:52:00 has no PV record
# 2017-03-11 08:53:00 has no PV record
# 2017-03-11 08:54:00 has no PV record
# 2017-03-11 08:55:00 has no PV record
# 2017-03-11 08:56:00 has no PV record
# 2017-03-11 08:57:00 has no PV record
# 2017-03-11 08:58:00 has no PV record
# 2017-03-11 08:59:00 has no PV record
# 2017-03-11 09:00:00 has no PV record
# 2017-03-11 09:01:00 has no PV record
# 2017-03-11 09:02:00 has no PV record
# 2017-03-11 09:03:00 has no PV record
# 2017-03-11 09:04:00 has no PV record
# 2017-03-11 09:05:00 has no PV record
# 2017-03-11 09:06:00 has no PV record
# 2017-03-11 09:07:00 has no PV record
# 2017-03-11 09:08:00 has no PV record
# 2017-03-11 09:09:00 has no PV record
# 2017-03-11 09:10:00 has no PV record
# 2017-03-11 09:11:00 has no PV record
# 2017-03-11 09:12:00 has no PV record
# 2017-03-11 09:13:00 has no PV record
# 2017-03-11 09:14:00 has no PV record
# 2017-03-11 09:15:00 has no PV record
# 2017-03-11 09:16:00 has no PV record
# 2017-03-11 09:16:50 has no PV record
# 2017-03-11 09:17:50 has no PV record
# 2017-03-11 09:18:50 has no PV record
# 2017-03-11 09:19:50 has no PV record
# 2017-03-11 09:20:50 has no PV record
# 2017-03-11 09:21:50 has no PV record
# 2017-03-11 09:22:50 has no PV record
# 2017-03-11 09:23:50 has no PV record
# 2017-03-11 09:24:50 has no PV record
# 2017-03-11 09:25:50 has no PV record
# 2017-03-11 09:26:50 has no PV record
# 2017-03-11 09:27:50 has no PV record
# 2017-03-11 09:28:50 has no PV record
# 2017-03-11 09:29:50 has no PV record
# 2017-03-11 09:30:50 has no PV record
# 2017-03-11 09:31:50 has no PV record
# 2017-03-11 09:32:50 has no PV record
# 2017-03-11 09:33:50 has no PV record
# 2017-03-11 09:34:50 has no PV record
# 2017-03-11 09:35:50 has no PV record
# 2017-03-11 09:36:50 has no PV record
# 2017-03-11 09:37:50 has no PV record
# 2017-03-11 09:38:50 has no PV record
# 2017-03-11 09:39:50 has no PV record
# 2017-03-11 09:40:50 has no PV record
# 2017-03-11 09:41:50 has no PV record
# 2017-03-11 09:42:50 has no PV record
# 2017-03-11 09:43:50 has no PV record
# 2017-03-11 09:44:50 has no PV record
# 2017-03-11 09:45:50 has no PV record
# 2017-03-11 09:46:50 has no PV record
# 2017-03-11 09:47:50 has no PV record
# 2017-03-11 09:48:50 has no PV record
# 2017-03-11 09:49:50 has no PV record
# 2017-03-11 09:50:50 has no PV record
# processed 1800 images/507963 images
# 2017-03-11 09:51:50 has no PV record
# 2017-03-11 09:52:50 has no PV record
# 2017-03-11 09:53:50 has no PV record
# 2017-03-11 09:54:50 has no PV record
# 2017-03-11 09:55:50 has no PV record
# 2017-03-11 09:56:50 has no PV record
# 2017-03-11 09:57:50 has no PV record
# 2017-03-11 09:58:50 has no PV record
# 2017-03-11 09:59:50 has no PV record
# 2017-03-11 10:00:50 has no PV record
# 2017-03-11 10:01:50 has no PV record
# 2017-03-11 10:02:50 has no PV record
# 2017-03-11 10:03:50 has no PV record
# 2017-03-11 10:04:50 has no PV record
# 2017-03-11 10:05:50 has no PV record
# 2017-03-11 10:06:50 has no PV record
# 2017-03-11 10:07:50 has no PV record
# 2017-03-11 10:08:50 has no PV record
# 2017-03-11 10:09:50 has no PV record
# 2017-03-11 10:10:50 has no PV record
# 2017-03-11 10:11:50 has no PV record
# 2017-03-11 10:12:50 has no PV record
# 2017-03-11 10:13:50 has no PV record
# 2017-03-11 10:14:50 has no PV record
# 2017-03-11 10:15:50 has no PV record
# 2017-03-11 10:16:50 has no PV record
# 2017-03-11 10:17:50 has no PV record
# 2017-03-11 10:18:50 has no PV record
# 2017-03-11 10:19:50 has no PV record
# 2017-03-11 10:20:50 has no PV record
# 2017-03-11 10:21:50 has no PV record
# 2017-03-11 10:22:50 has no PV record
# 2017-03-11 10:23:50 has no PV record
# 2017-03-11 10:24:50 has no PV record
# 2017-03-11 10:25:50 has no PV record
# 2017-03-11 10:26:50 has no PV record
# 2017-03-11 10:27:50 has no PV record
# 2017-03-11 10:28:50 has no PV record
# 2017-03-11 10:29:50 has no PV record
# 2017-03-11 10:30:50 has no PV record
# 2017-03-11 10:31:50 has no PV record
# 2017-03-11 10:32:50 has no PV record
# 2017-03-11 10:33:40 has no PV record
# 2017-03-11 10:34:40 has no PV record
# 2017-03-11 10:35:40 has no PV record
# 2017-03-11 10:36:40 has no PV record
# 2017-03-11 10:37:40 has no PV record
# 2017-03-11 10:38:40 has no PV record
# 2017-03-11 10:39:40 has no PV record
# 2017-03-11 10:40:40 has no PV record
# 2017-03-11 10:41:40 has no PV record
# 2017-03-11 10:42:40 has no PV record
# 2017-03-11 10:43:40 has no PV record
# 2017-03-11 10:44:40 has no PV record
# 2017-03-11 10:45:40 has no PV record
# 2017-03-11 10:46:40 has no PV record
# 2017-03-11 10:47:40 has no PV record
# 2017-03-11 10:48:40 has no PV record
# 2017-03-11 10:49:40 has no PV record
# 2017-03-11 10:50:40 has no PV record
# 2017-03-11 10:51:40 has no PV record
# 2017-03-11 10:52:40 has no PV record
# 2017-03-11 10:53:40 has no PV record
# 2017-03-11 10:54:40 has no PV record
# 2017-03-11 10:55:40 has no PV record
# 2017-03-11 10:56:40 has no PV record
# 2017-03-11 10:57:40 has no PV record
# 2017-03-11 10:58:40 has no PV record
# 2017-03-11 10:59:40 has no PV record
# 2017-03-11 11:00:40 has no PV record
# 2017-03-11 11:01:40 has no PV record
# 2017-03-11 11:02:40 has no PV record
# 2017-03-11 11:03:40 has no PV record
# 2017-03-11 11:04:40 has no PV record
# 2017-03-11 11:05:40 has no PV record
# 2017-03-11 11:06:40 has no PV record
# 2017-03-11 11:07:40 has no PV record
# 2017-03-11 11:08:40 has no PV record
# 2017-03-11 11:09:40 has no PV record
# 2017-03-11 11:10:40 has no PV record
# 2017-03-11 11:11:40 has no PV record
# 2017-03-11 11:12:40 has no PV record
# 2017-03-11 11:13:40 has no PV record
# 2017-03-11 11:14:40 has no PV record
# 2017-03-11 11:15:40 has no PV record
# 2017-03-11 11:16:40 has no PV record
# 2017-03-11 11:17:40 has no PV record
# 2017-03-11 11:18:40 has no PV record
# 2017-03-11 11:19:40 has no PV record
# 2017-03-11 11:20:40 has no PV record
# 2017-03-11 11:21:40 has no PV record
# 2017-03-11 11:22:40 has no PV record
# 2017-03-11 11:23:40 has no PV record
# 2017-03-11 11:24:40 has no PV record
# 2017-03-11 11:25:40 has no PV record
# 2017-03-11 11:26:40 has no PV record
# 2017-03-11 11:27:40 has no PV record
# 2017-03-11 11:28:40 has no PV record
# 2017-03-11 11:29:40 has no PV record
# 2017-03-11 11:30:40 has no PV record
# processed 1900 images/507963 images
# 2017-03-11 11:31:40 has no PV record
# 2017-03-11 11:32:40 has no PV record
# 2017-03-11 11:33:40 has no PV record
# 2017-03-11 11:34:40 has no PV record
# 2017-03-11 11:35:40 has no PV record
# 2017-03-11 11:36:40 has no PV record
# 2017-03-11 11:37:40 has no PV record
# 2017-03-11 11:38:40 has no PV record
# 2017-03-11 11:39:40 has no PV record
# 2017-03-11 11:40:40 has no PV record
# 2017-03-11 11:41:40 has no PV record
# 2017-03-11 11:42:40 has no PV record
# 2017-03-11 11:43:40 has no PV record
# 2017-03-11 11:44:40 has no PV record
# 2017-03-11 11:45:40 has no PV record
# 2017-03-11 11:46:40 has no PV record
# 2017-03-11 11:47:40 has no PV record
# 2017-03-11 11:48:40 has no PV record
# 2017-03-11 11:49:40 has no PV record
# 2017-03-11 11:50:40 has no PV record
# 2017-03-11 11:51:40 has no PV record
# 2017-03-11 11:52:40 has no PV record
# 2017-03-11 11:53:40 has no PV record
# 2017-03-11 11:54:40 has no PV record
# 2017-03-11 11:55:40 has no PV record
# 2017-03-11 11:56:40 has no PV record
# 2017-03-11 11:57:40 has no PV record
# 2017-03-11 11:58:40 has no PV record
# 2017-03-11 11:59:40 has no PV record
# 2017-03-11 12:00:30 has no PV record
# 2017-03-11 12:01:30 has no PV record
# 2017-03-11 12:02:30 has no PV record
# 2017-03-11 12:03:30 has no PV record
# 2017-03-11 12:04:30 has no PV record
# 2017-03-11 12:05:30 has no PV record
# 2017-03-11 12:06:30 has no PV record
# 2017-03-11 12:07:30 has no PV record
# 2017-03-11 12:08:30 has no PV record
# 2017-03-11 12:09:30 has no PV record
# 2017-03-11 12:10:30 has no PV record
# 2017-03-11 12:11:30 has no PV record
# 2017-03-11 12:12:30 has no PV record
# 2017-03-11 12:13:30 has no PV record
# 2017-03-11 12:14:30 has no PV record
# 2017-03-11 12:15:30 has no PV record
# 2017-03-11 12:16:30 has no PV record
# 2017-03-11 12:17:30 has no PV record
# 2017-03-11 12:18:30 has no PV record
# 2017-03-11 12:19:30 has no PV record
# 2017-03-11 12:20:30 has no PV record
# 2017-03-11 12:21:30 has no PV record
# 2017-03-11 12:22:30 has no PV record
# 2017-03-11 12:23:30 has no PV record
# 2017-03-11 12:24:30 has no PV record
# ...
# 2019-12-30 12:54:10 has no PV record
# 2019-12-30 12:55:10 has no PV record
# 2019-12-30 12:56:10 has no PV record
# 2019-12-30 12:57:10 has no PV record
# 2019-12-30 12:58:10 has no PV record
# 2019-12-30 12:59:10 has no PV record
# 2019-12-30 13:00:10 has no PV record
# 2019-12-30 13:01:10 has no PV record
# 2019-12-30 13:02:10 has no PV record
# 2019-12-30 13:03:10 has no PV record
# 2019-12-30 13:04:10 has no PV record
# 2019-12-30 13:05:10 has no PV record
# 2019-12-30 13:06:10 has no PV record
# 2019-12-30 13:07:10 has no PV record
# 2019-12-30 13:08:10 has no PV record
# 2019-12-30 13:09:10 has no PV record
# 2019-12-30 13:10:10 has no PV record
# 2019-12-30 13:11:10 has no PV record
# 2019-12-30 13:12:10 has no PV record
# 2019-12-30 13:13:10 has no PV record
# 2019-12-30 13:14:10 has no PV record
# 2019-12-30 13:15:10 has no PV record
# 2019-12-30 13:16:10 has no PV record
# 2019-12-30 13:17:10 has no PV record
# 2019-12-30 13:18:10 has no PV record
# 2019-12-30 13:19:10 has no PV record
# 2019-12-30 13:20:10 has no PV record
# 2019-12-30 13:21:10 has no PV record
# 2019-12-30 13:22:10 has no PV record
# 2019-12-30 13:23:10 has no PV record
# 2019-12-30 13:24:10 has no PV record
# 2019-12-30 13:25:10 has no PV record
# 2019-12-30 13:26:10 has no PV record
# 2019-12-30 13:27:10 has no PV record
# 2019-12-30 13:28:10 has no PV record
# 2019-12-30 13:29:10 has no PV record
# 2019-12-30 13:30:10 has no PV record
# 2019-12-30 13:31:10 has no PV record
# 2019-12-30 13:32:10 has no PV record
# 2019-12-30 13:33:10 has no PV record
# 2019-12-30 13:34:10 has no PV record
# 2019-12-30 13:35:10 has no PV record
# 2019-12-30 13:36:10 has no PV record
# 2019-12-30 13:37:10 has no PV record
# 2019-12-30 13:38:10 has no PV record
# 2019-12-30 13:39:10 has no PV record
# 2019-12-30 13:40:10 has no PV record
# 2019-12-30 13:41:10 has no PV record
# 2019-12-30 13:42:10 has no PV record
# 2019-12-30 13:43:10 has no PV record
# 2019-12-30 13:44:10 has no PV record
# 2019-12-30 13:45:10 has no PV record
# 2019-12-30 13:46:10 has no PV record
# 2019-12-30 13:47:10 has no PV record
# 2019-12-30 13:48:10 has no PV record
# 2019-12-30 13:49:10 has no PV record
# 2019-12-30 13:50:10 has no PV record
# 2019-12-30 13:51:10 has no PV record
# 2019-12-30 13:52:10 has no PV record
# 2019-12-30 13:53:10 has no PV record
# 2019-12-30 13:54:10 has no PV record
# 2019-12-30 13:55:10 has no PV record
# 2019-12-30 13:56:10 has no PV record
# 2019-12-30 13:57:10 has no PV record
# 2019-12-30 13:58:10 has no PV record
# processed 507600 images/507963 images
# 2019-12-30 13:59:10 has no PV record
# 2019-12-30 14:00:10 has no PV record
# 2019-12-30 14:01:10 has no PV record
# 2019-12-30 14:02:10 has no PV record
# 2019-12-30 14:03:10 has no PV record
# 2019-12-30 14:04:10 has no PV record
# 2019-12-30 14:05:10 has no PV record
# 2019-12-30 14:06:10 has no PV record
# 2019-12-30 14:07:10 has no PV record
# 2019-12-30 14:08:10 has no PV record
# 2019-12-30 14:09:10 has no PV record
# 2019-12-30 14:10:10 has no PV record
# 2019-12-30 14:11:10 has no PV record
# 2019-12-30 14:12:10 has no PV record
# 2019-12-30 14:13:10 has no PV record
# 2019-12-30 14:14:10 has no PV record
# 2019-12-30 14:15:10 has no PV record
# 2019-12-30 14:16:10 has no PV record
# 2019-12-30 14:17:10 has no PV record
# 2019-12-30 14:18:10 has no PV record
# 2019-12-30 14:18:40 has no PV record
# 2019-12-30 14:19:40 has no PV record
# 2019-12-30 14:20:40 has no PV record
# 2019-12-30 14:21:40 has no PV record
# 2019-12-30 14:22:40 has no PV record
# 2019-12-30 14:23:40 has no PV record
# 2019-12-30 14:24:40 has no PV record
# 2019-12-30 14:25:40 has no PV record
# 2019-12-30 14:26:40 has no PV record
# 2019-12-30 14:27:40 has no PV record
# 2019-12-30 14:28:40 has no PV record
# 2019-12-30 14:29:40 has no PV record
# 2019-12-30 14:30:40 has no PV record
# 2019-12-30 14:31:40 has no PV record
# 2019-12-30 14:32:40 has no PV record
# 2019-12-30 14:33:40 has no PV record
# 2019-12-30 14:34:40 has no PV record
# 2019-12-30 14:35:40 has no PV record
# 2019-12-30 14:36:40 has no PV record
# 2019-12-30 14:37:40 has no PV record
# 2019-12-30 14:38:40 has no PV record
# 2019-12-30 14:39:40 has no PV record
# 2019-12-30 14:40:40 has no PV record
# 2019-12-30 14:41:40 has no PV record
# 2019-12-30 14:42:40 has no PV record
# 2019-12-30 14:43:40 has no PV record
# 2019-12-30 14:44:40 has no PV record
# 2019-12-30 14:45:40 has no PV record
# 2019-12-30 14:46:40 has no PV record
# 2019-12-30 14:47:40 has no PV record
# 2019-12-30 14:48:40 has no PV record
# 2019-12-30 14:49:40 has no PV record
# 2019-12-30 14:50:40 has no PV record
# 2019-12-30 14:51:40 has no PV record
# 2019-12-30 14:52:40 has no PV record
# 2019-12-30 14:53:40 has no PV record
# 2019-12-30 14:54:40 has no PV record
# 2019-12-30 14:55:40 has no PV record
# 2019-12-30 14:56:40 has no PV record
# 2019-12-30 14:57:40 has no PV record
# 2019-12-30 14:58:40 has no PV record
# 2019-12-30 14:59:40 has no PV record
# 2019-12-30 15:00:40 has no PV record
# 2019-12-30 15:01:40 has no PV record
# 2019-12-30 15:02:40 has no PV record
# 2019-12-30 15:03:40 has no PV record
# 2019-12-30 15:04:40 has no PV record
# 2019-12-30 15:05:40 has no PV record
# 2019-12-30 15:06:40 has no PV record
# 2019-12-30 15:07:40 has no PV record
# 2019-12-30 15:08:40 has no PV record
# 2019-12-30 15:09:40 has no PV record
# 2019-12-30 15:10:40 has no PV record
# 2019-12-30 15:11:40 has no PV record
# 2019-12-30 15:12:40 has no PV record
# 2019-12-30 15:13:40 has no PV record
# 2019-12-30 15:14:40 has no PV record
# 2019-12-30 15:15:40 has no PV record
# 2019-12-30 15:16:40 has no PV record
# 2019-12-30 15:17:40 has no PV record
# 2019-12-30 15:18:40 has no PV record
# 2019-12-30 15:19:40 has no PV record
# 2019-12-30 15:20:40 has no PV record
# 2019-12-30 15:21:40 has no PV record
# 2019-12-30 15:22:40 has no PV record
# 2019-12-30 15:23:40 has no PV record
# 2019-12-30 15:24:40 has no PV record
# 2019-12-30 15:25:40 has no PV record
# 2019-12-30 15:26:40 has no PV record
# 2019-12-30 15:27:40 has no PV record
# 2019-12-30 15:28:40 has no PV record
# 2019-12-30 15:29:40 has no PV record
# 2019-12-30 15:30:40 has no PV record
# 2019-12-30 15:31:40 has no PV record
# 2019-12-30 15:32:40 has no PV record
# 2019-12-30 15:33:40 has no PV record
# 2019-12-30 15:34:40 has no PV record
# 2019-12-30 15:35:40 has no PV record
# 2019-12-30 15:36:40 has no PV record
# 2019-12-30 15:37:40 has no PV record
# processed 507700 images/507963 images
# 2019-12-30 15:38:40 has no PV record
# 2019-12-30 15:39:40 has no PV record
# 2019-12-30 15:40:40 has no PV record
# 2019-12-30 15:41:40 has no PV record
# 2019-12-30 15:42:40 has no PV record
# 2019-12-30 15:43:40 has no PV record
# 2019-12-30 15:44:40 has no PV record
# 2019-12-30 15:45:40 has no PV record
# 2019-12-30 15:46:40 has no PV record
# 2019-12-30 15:47:40 has no PV record
# 2019-12-30 15:48:40 has no PV record
# 2019-12-30 15:49:40 has no PV record
# 2019-12-30 15:50:40 has no PV record
# 2019-12-30 15:51:40 has no PV record
# 2019-12-30 15:52:40 has no PV record
# 2019-12-30 15:53:40 has no PV record
# 2019-12-30 15:54:40 has no PV record
# 2019-12-30 15:55:40 has no PV record
# 2019-12-30 15:56:40 has no PV record
# 2019-12-30 15:57:40 has no PV record
# 2019-12-30 15:58:40 has no PV record
# 2019-12-30 15:59:40 has no PV record
# 2019-12-30 16:00:40 has no PV record
# 2019-12-30 16:01:40 has no PV record
# 2019-12-30 16:02:40 has no PV record
# 2019-12-30 16:03:40 has no PV record
# 2019-12-30 16:04:40 has no PV record
# 2019-12-30 16:05:40 has no PV record
# 2019-12-30 16:06:40 has no PV record
# 2019-12-30 16:07:40 has no PV record
# 2019-12-30 16:08:40 has no PV record
# 2019-12-30 16:09:40 has no PV record
# 2019-12-30 16:10:40 has no PV record
# 2019-12-30 16:11:40 has no PV record
# 2019-12-30 16:12:40 has no PV record
# 2019-12-30 16:13:40 has no PV record
# 2019-12-30 16:14:40 has no PV record
# 2019-12-30 16:15:40 has no PV record
# 2019-12-30 16:16:40 has no PV record
# 2019-12-30 16:17:40 has no PV record
# 2019-12-30 16:18:40 has no PV record
# 2019-12-30 16:19:40 has no PV record
# 2019-12-30 16:20:40 has no PV record
# 2019-12-30 16:21:40 has no PV record
# 2019-12-30 16:22:40 has no PV record
# 2019-12-30 16:23:40 has no PV record
# 2019-12-30 16:24:40 has no PV record
# 2019-12-30 16:25:40 has no PV record
# 2019-12-30 16:26:40 has no PV record
# 2019-12-30 16:27:40 has no PV record
# 2019-12-30 16:28:40 has no PV record
# 2019-12-30 16:29:40 has no PV record
# 2019-12-30 16:30:40 has no PV record
# 2019-12-30 16:31:40 has no PV record
# 2019-12-30 16:32:00 has no PV record
# 2019-12-30 16:33:00 has no PV record
# 2019-12-30 16:34:00 has no PV record
# 2019-12-30 16:35:00 has no PV record
# 2019-12-30 16:36:00 has no PV record
# 2019-12-30 16:37:00 has no PV record
# 2019-12-30 16:38:00 has no PV record
# 2019-12-30 16:39:00 has no PV record
# 2019-12-30 16:40:00 has no PV record
# 2019-12-30 16:41:00 has no PV record
# 2019-12-30 16:42:00 has no PV record
# 2019-12-30 16:43:00 has no PV record
# 2019-12-30 16:44:00 has no PV record
# 2019-12-30 16:45:00 has no PV record
# 2019-12-30 16:46:00 has no PV record
# 2019-12-30 16:47:00 has no PV record
# 2019-12-30 16:48:00 has no PV record
# 2019-12-30 16:49:00 has no PV record
# 2019-12-30 16:50:00 has no PV record
# 2019-12-30 16:51:00 has no PV record
# 2019-12-30 16:52:00 has no PV record
# 2019-12-30 16:53:00 has no PV record
# 2019-12-30 16:54:00 has no PV record
# 2019-12-30 16:55:00 has no PV record
# 2019-12-30 16:56:00 has no PV record
# 2019-12-30 16:57:00 has no PV record
# 2019-12-30 16:58:00 has no PV record
# 2019-12-30 16:59:00 has no PV record
# 2019-12-30 17:00:00 has no PV record
# 2019-12-30 17:01:00 has no PV record
# 2019-12-30 17:02:00 has no PV record
# 2019-12-30 17:03:00 has no PV record
# 2019-12-30 17:04:00 has no PV record
# 2019-12-30 17:05:00 has no PV record
# 2019-12-30 17:06:00 has no PV record
# 2019-12-30 17:07:00 has no PV record
# 2019-12-30 17:08:00 has no PV record
# 2019-12-30 17:09:00 has no PV record
# 2019-12-30 17:10:00 has no PV record
# 2019-12-30 17:11:00 has no PV record
# 2019-12-30 17:12:00 has no PV record
# 2019-12-30 17:13:00 has no PV record
# 2019-12-30 17:14:00 has no PV record
# 2019-12-30 17:15:00 has no PV record
# 2019-12-30 17:16:00 has no PV record
# 2019-12-30 17:17:00 has no PV record
# processed 507800 images/507963 images
# 2019-12-30 17:18:00 has no PV record
# 2019-12-30 17:19:00 has no PV record
# 2019-12-30 17:20:00 has no PV record
# 2019-12-30 17:21:00 has no PV record
# 2019-12-30 17:22:00 has no PV record
# 2019-12-30 17:23:00 has no PV record
# 2019-12-30 17:24:00 has no PV record
# 2019-12-30 17:25:00 has no PV record
# 2019-12-30 17:26:00 has no PV record
# 2019-12-30 17:27:00 has no PV record
# 2019-12-30 17:28:00 has no PV record
# 2019-12-30 17:29:00 has no PV record
# 2019-12-30 17:30:00 has no PV record
# 2019-12-30 17:31:00 has no PV record
# 2019-12-30 17:32:00 has no PV record
# 2019-12-30 17:33:00 has no PV record
# 2019-12-30 17:34:00 has no PV record
# 2019-12-30 17:35:00 has no PV record
# 2019-12-30 17:36:00 has no PV record
# 2019-12-30 17:37:00 has no PV record
# 2019-12-30 17:38:00 has no PV record
# 2019-12-30 17:39:00 has no PV record
# 2019-12-30 17:40:00 has no PV record
# 2019-12-30 17:41:00 has no PV record
# 2019-12-30 17:42:00 has no PV record
# 2019-12-30 17:43:00 has no PV record
# 2019-12-30 17:44:00 has no PV record
# 2019-12-30 17:45:00 has no PV record
# 2019-12-30 17:46:00 has no PV record
# 2019-12-30 17:47:00 has no PV record
# 2019-12-30 17:48:00 has no PV record
# 2019-12-30 17:49:00 has no PV record
# 2019-12-30 17:50:00 has no PV record
# 2019-12-30 17:51:00 has no PV record
# 2019-12-30 17:52:00 has no PV record
# 2019-12-30 17:53:00 has no PV record
# 2019-12-30 17:54:00 has no PV record
# 2019-12-30 17:55:00 has no PV record
# 2019-12-30 17:56:00 has no PV record
# 2019-12-30 17:57:00 has no PV record
# 2019-12-30 17:58:00 has no PV record
# 2019-12-30 17:59:00 has no PV record
# 2019-12-30 18:00:00 has no PV record
# 2019-12-30 18:01:00 has no PV record
# 2019-12-30 18:02:00 has no PV record
# 2019-12-30 18:03:00 has no PV record
# 2019-12-30 18:04:00 has no PV record
# 2019-12-30 18:05:00 has no PV record
# 2019-12-30 18:06:00 has no PV record
# 2019-12-30 18:07:00 has no PV record
# 2019-12-30 18:08:00 has no PV record
# 2019-12-30 18:09:00 has no PV record
# 2019-12-30 18:10:00 has no PV record
# 2019-12-30 18:11:00 has no PV record
# 2019-12-30 18:12:00 has no PV record
# 2019-12-30 18:13:00 has no PV record
# 2019-12-30 18:14:00 has no PV record
# 2019-12-30 18:15:00 has no PV record
# 2019-12-30 18:16:00 has no PV record
# 2019-12-30 18:17:00 has no PV record
# 2019-12-30 18:18:00 has no PV record
# 2019-12-30 18:19:00 has no PV record
# 2019-12-30 18:20:00 has no PV record
# 2019-12-30 18:21:00 has no PV record
# 2019-12-30 18:22:00 has no PV record
# 2019-12-30 18:23:00 has no PV record
# 2019-12-30 18:24:00 has no PV record
# 2019-12-30 18:25:00 has no PV record
# 2019-12-30 18:26:00 has no PV record
# 2019-12-30 18:27:00 has no PV record
# 2019-12-30 18:28:00 has no PV record
# 2019-12-30 18:29:00 has no PV record
# 2019-12-30 18:30:00 has no PV record
# 2019-12-30 18:31:00 has no PV record
# 2019-12-30 18:32:00 has no PV record
# 2019-12-30 18:33:00 has no PV record
# 2019-12-30 18:34:00 has no PV record
# 2019-12-30 18:35:00 has no PV record
# 2019-12-30 18:36:00 has no PV record
# 2019-12-30 18:37:00 has no PV record
# 2019-12-30 18:38:00 has no PV record
# 2019-12-30 18:39:00 has no PV record
# 2019-12-30 18:40:00 has no PV record
# 2019-12-30 18:41:00 has no PV record
# 2019-12-30 18:42:00 has no PV record
# 2019-12-30 18:43:00 has no PV record
# 2019-12-30 18:44:00 has no PV record
# 2019-12-30 18:45:00 has no PV record
# 2019-12-30 18:46:00 has no PV record
# 2019-12-30 18:47:00 has no PV record
# 2019-12-30 18:48:00 has no PV record
# 2019-12-30 18:49:00 has no PV record
# 2019-12-30 18:50:00 has no PV record
# 2019-12-30 18:51:00 has no PV record
# 2019-12-30 18:52:00 has no PV record
# 2019-12-30 18:53:00 has no PV record
# 2019-12-30 18:54:00 has no PV record
# 2019-12-30 18:55:00 has no PV record
# 2019-12-30 18:56:00 has no PV record
# 2019-12-30 18:57:00 has no PV record
# processed 507900 images/507963 images
# 2019-12-30 18:58:00 has no PV record
# 2019-12-30 18:59:00 has no PV record
# 2019-12-30 19:00:00 has no PV record
# 2019-12-30 19:01:00 has no PV record
# 2019-12-30 19:02:00 has no PV record
# 2019-12-30 19:03:00 has no PV record
# 2019-12-30 19:04:00 has no PV record
# 2019-12-30 19:05:00 has no PV record
# 2019-12-30 19:06:00 has no PV record
# 2019-12-30 19:07:00 has no PV record
# 2019-12-30 19:08:00 has no PV record
# 2019-12-30 19:09:00 has no PV record
# 2019-12-30 19:10:00 has no PV record
# 2019-12-30 19:11:00 has no PV record
# 2019-12-30 19:12:00 has no PV record
# 2019-12-30 19:13:00 has no PV record
# 2019-12-30 19:14:00 has no PV record
# 2019-12-30 19:15:00 has no PV record
# 2019-12-30 19:16:00 has no PV record
# 2019-12-30 19:17:00 has no PV record
# 2019-12-30 19:18:00 has no PV record
# 2019-12-30 19:19:00 has no PV record
# 2019-12-30 19:20:00 has no PV record
# 2019-12-30 19:21:00 has no PV record
# 2019-12-30 19:22:00 has no PV record
# 2019-12-30 19:23:00 has no PV record
# 2019-12-30 19:24:00 has no PV record
# 2019-12-30 19:25:00 has no PV record
# 2019-12-30 19:26:00 has no PV record
# 2019-12-30 19:27:00 has no PV record
# 2019-12-30 19:28:00 has no PV record
# 2019-12-30 19:29:00 has no PV record
# 2019-12-30 19:30:00 has no PV record
# 2019-12-30 19:31:00 has no PV record
# 2019-12-30 19:32:00 has no PV record
# 2019-12-30 19:33:00 has no PV record
# 2019-12-30 19:34:00 has no PV record
# 2019-12-30 19:35:00 has no PV record
# 2019-12-30 19:36:00 has no PV record
# 2019-12-30 19:37:00 has no PV record
# 2019-12-30 19:38:00 has no PV record
# 2019-12-30 19:39:00 has no PV record
# 2019-12-30 19:40:00 has no PV record
# 2019-12-30 19:41:00 has no PV record
# 2019-12-30 19:42:00 has no PV record
# 2019-12-30 19:43:00 has no PV record
# 2019-12-30 19:44:00 has no PV record
# 2019-12-30 19:45:00 has no PV record
# 2019-12-30 19:46:00 has no PV record
# 2019-12-30 19:47:00 has no PV record
# 2019-12-30 19:48:00 has no PV record
# 2019-12-30 19:49:00 has no PV record
# 2019-12-30 19:50:00 has no PV record
# 2019-12-30 19:51:00 has no PV record
# 2019-12-30 19:52:00 has no PV record
# 2019-12-30 19:53:00 has no PV record
# 2019-12-30 19:54:00 has no PV record
# 2019-12-30 19:55:00 has no PV record
# 2019-12-30 19:56:00 has no PV record
# 2019-12-30 19:57:00 has no PV record
# 2019-12-30 19:58:00 has no PV record
# 2019-12-30 19:59:00 has no PV record
# time_elapsed 11284.870593

# %%
# Cropping relevant information
all_times = all_times[validity_mask]
all_images = all_images[validity_mask]
pv_outputs = pv_outputs[validity_mask]

# %%
#storing information
np.save(os.path.join(output_folder,'all_times_highfreq.npy'),all_times)
np.save(os.path.join(output_folder,'all_images_highfreq.npy'), all_images)
np.save(os.path.join(output_folder,'pv_outputs_highfreq.npy'), pv_outputs)

# %%
all_times.shape
# Out:
# (368159,)

# %%
all_images.shape
# Out:
# (368159, 64, 64, 3)

# %% [markdown]
# ### Filter out repeating images

# %%
# Load back in the previously processed times, images, and PV_outputs
all_times = np.load(os.path.join(output_folder,'all_times_highfreq.npy'), allow_pickle = True)
all_images = np.load(os.path.join(output_folder,'all_images_highfreq.npy'), allow_pickle = True)
pv_outputs = np.load(os.path.join(output_folder,'pv_outputs_highfreq.npy'), allow_pickle = True)

# %%
# Filter for repeating images (the OpenCV video capture function would sometimes fail to seek the correct frame 
# and instead erroneously repeat the current frame)
all_images_16 = all_images.astype('int16')

# Calculated the change within two continuous image
all_images_diff = all_images_16[1:] - all_images_16[:-1]
all_images_diff_sum = np.sum(np.abs(all_images_diff), axis = (1,2,3))

# create mask that record repeating status
is_repeating_mask = np.zeros(all_images.shape[0],dtype = bool)
is_repeating_mask[1:] = (all_images_diff_sum == 0)

# Cropping relevant information
all_times = all_times[~is_repeating_mask]
all_images = all_images[~is_repeating_mask]
pv_outputs = pv_outputs[~is_repeating_mask]

# %%
all_times.shape
# Out:
# (363375,)

# %%
#storing information
np.save(os.path.join(output_folder,'all_times_highfreq.npy'),all_times)
np.save(os.path.join(output_folder,'all_images_highfreq.npy'), all_images)
np.save(os.path.join(output_folder,'pv_outputs_highfreq.npy'), pv_outputs)

# %%
def store_trainval_test(all_times,image_log,pv_log,pred_folder):
    
    ## Splitting into Trainval and Test set 
    idx_test = find_idx_with_dates(all_times,test_dates)
    image_log_test = image_log[idx_test]
    pv_log_test = pv_log[idx_test]
    times_test = all_times[idx_test]

    # the rest become the trainval set
    mask_trainval = np.ones_like(pv_log,dtype = bool)
    mask_trainval[idx_test] = 0
    image_log_trainval = image_log[mask_trainval]
    pv_log_trainval = pv_log[mask_trainval]
    times_trainval = all_times[mask_trainval]
    
    print("times_trainval.shape",times_trainval.shape)
    print("image_log_trainval.shape",image_log_trainval.shape)
    print("pv_log_trainval.shape",pv_log_trainval.shape)
    
    print("times_test.shape",times_test.shape)
    print("image_log_test.shape",image_log_test.shape)
    print("pv_log_test.shape",pv_log_test.shape)
    
    #storing information
    # storing the training set
    np.save(os.path.join(pred_folder,'image_log_trainval.npy'), image_log_trainval)
    np.save(os.path.join(pred_folder,'pv_log_trainval.npy'), pv_log_trainval)
    np.save(os.path.join(pred_folder,'times_trainval.npy'),times_trainval)

    # storing the testing set
    np.save(os.path.join(pred_folder,'image_log_test.npy'), image_log_test)
    np.save(os.path.join(pred_folder,'pv_log_test.npy'), pv_log_test)
    np.save(os.path.join(pred_folder,'times_test.npy'),times_test)

# %%
store_trainval_test(all_times,all_images,pv_outputs,pred_folder)
# Out:
# times_trainval.shape (349372,)
# image_log_trainval.shape (349372, 64, 64, 3)
# pv_log_trainval.shape (349372,)
# times_test.shape (14003,)
# image_log_test.shape (14003, 64, 64, 3)
# pv_log_test.shape (14003,)

# %%
## Check the pv distribution
import matplotlib.pyplot as plt

pv_log_test = np.load(os.path.join(pred_folder,'pv_log_test.npy'))
pv_log_trainval = np.load(os.path.join(pred_folder,'pv_log_trainval.npy'))



plt.figure(figsize=(5,3))
plt.hist(pv_log_test, histtype='stepfilled', color='blue', density=True, bins=50, alpha=0.5,label='Test set')
plt.hist(pv_log_trainval, histtype='stepfilled', color='red', density=True, bins=50, alpha=0.5,label='Development set')
plt.ylabel('Density')
plt.xlabel('PV power generation (kW)')
plt.legend()
plt.savefig('pv_nowcast_density.pdf',bbox_inches='tight')

# %%
f,ax = plt.subplots(1,2, sharex=True, sharey=True, figsize=(10,3))
ax[0].hist(pv_log_trainval, histtype='stepfilled', color='red', density=True, bins=50, alpha=0.5,label='Development set')
ax[0].set_title('Development set')
ax[1].hist(pv_log_test, histtype='stepfilled', color='blue', density=True, bins=50, alpha=0.5,label='Test set')
ax[1].set_title('Test set')
ax[0].set_ylabel('Density')
ax[0].set_xlabel('PV power generation (kW)')
ax[1].set_xlabel('PV power generation (kW)')
#ax[0].legend()
plt.savefig('pv_nowcast_density_sep.pdf',bbox_inches='tight')
